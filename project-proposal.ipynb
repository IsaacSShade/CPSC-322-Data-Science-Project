# %% [markdown]
# # Project Proposal - Mushrooms Edibility Classification
# By Aiden Tabrah and Valon Haslem

# %% [markdown]
# ### Dataset Description

# %% [markdown]
# #### 1) Overview:
# [Weather Category Dataset](https://www.kaggle.com/datasets/muthuj7/weather-dataset) is a .csv file with 96.5k instances and 12 attributes.
# #### 2) Description:
# We will be using 10 non-classification attributes for training our classifiers, out of the 12. The layoyut of the dataset is as follows:
#
# **Summary**                     - Various classification labels such as "Partly Cloudy" or "Mostly Cloudy"
#  ___
# **Date**                 - Dates from 2005 to 2016
# **Precip-type**               - rain, snow, or other
# **Temperature (C)**                 - Temperature in celsius from -21.8 to 39.9
# **Apparent Temperature (C)**                   -  How it "feels" outside due to wind or other conditions. Ranges from -27.7 to 39.3
# **Humidity**                      - Percentage between 0.00 and 1.00
# **Wind Speed (km/h)**           - Wind speed in kilometers per hour, from 0 to 63.9
# **Wind Bearing (degrees)**              - Wind direction from 0 to 359
# **Visibility (km)**                 - How far one should be able to see, in kilometers.
# **Pressure (millibars)**               - Pressure from 0 to 1.05k
# **Loud Cover** - Potentially cloud cover? All data values are 0.0 though. (Will not be used)
# **Daily Summary** - A more descriptive classification of the data, that isn't standardized and varies more often. (Will not be used)

# %% [markdown]
# ### Implementation / Technical Merit

# %% [markdown]
# 1) Anticipated challenges in pre-processing and/or classification (e.g., missing values, class distribution, etc.)
#
#
# Loud cover and Daily summary are two classifiers that we could potentially use, but it appears to be text data that isn't easy to classify and use the classifiers on. There also appears to be flawed data with pressure (as some values say zero when they shouldn't say zero) so some cleaning may be necessary to clean the set before classification.
#
# Another issue is that we cannot assume these variables to be independent, which is a critical component of Naive Bayes classifier. Since pressure and temperature or pressure and humidity may tend to move together, it is not an assumption we can make when trying to predict weather. This also means some classes may fall into distinct clusters, so we need to be particular in the classifiers that we use.
#
# 2) If the number of attributes is large, how will you explore feature selection techniques to pare down the attributes?
#
#
# The full dataset has 12 columns with some dependent attributes, meaning we may have excessive attributes that don't actually provide new information (and may just overcomplicate our classifier). This implies we may only need to take a subset of the data to construct the most accurate classifier. Fortunately, we have classifer by classifier methods to deal with this issue, and we can evaluate by taking subsets of classifers and testing accuracy. We can test the two extremes (all features, or only a single feature) and compare results, and hopefully look for a perfect medium.

# %% [markdown]
# ### Potential Impact of Results

# %% [markdown]
# 1) __Why are these results useful?__
#
# These results are useful because one could use this dataset to aid a forecaster in predicting weather patterns. This is useful in normal cases, where people may just be trying to plan their outfits for the day, and in extreme cases, where it could be used to predict inclement and disastrous weather.
#
# 2) __Who are stakeholders (users/groups that are impacted by the outcome of the project) interested in these results?__
# The stakeholders are anyone trying to predict the weather, which includes trained meteorologists and normal people trying to go about their day. Since weather is a key component of how people perceive their day, being able to accurately predict it is essential.

# %% [markdown]
# ### Citations

# %% [markdown]
# - [https://www.kaggle.com/datasets/muthuj7/weather-dataset (Weather Dataset)](https://www.kaggle.com/datasets/muthuj7/weather-dataset)
# - [https://www.nature.com/articles/s41586-024-08252-9 (Article about using ML to predict weather)](https://www.nature.com/articles/s41586-024-08252-9)
